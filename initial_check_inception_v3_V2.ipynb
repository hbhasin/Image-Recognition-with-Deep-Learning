# %%
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
model = InceptionV3(weights='imagenet')
# Out:
# A local file was found, but it seems to be incomplete or outdated.
# ...

# %%
# save fine-tuning model for offline prediction purposes
model.save('inception_v3_imagenet_model.h5')

# %%
def pred(img_for_recog):
    img = image.load_img(img_for_recog, target_size = (299, 299, 3))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model.predict(x)
    # decode the results into a list of tuples (class, description, probability)
    # (one such list for each sample in the batch)
    print('Predicted:', decode_predictions(preds, top = 5)[0])

# %%
def display_img(img_for_display):
    img = load_img(img_for_display)
    plt.figure(figsize = (3,3))
    plt.imshow(img)
    plt.axis('off')
    plt.title(img_for_display.rsplit('/')[1].rsplit('.')[0])
    plt.show()

# %%
img_path = 'images/noodles_fried.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n07831146', 'carbonara', 0.72230476), ('n07714990', 'broccoli', 0.1056917), ('n07579787', 'plate', 0.028160635), ('n07716358', 'zucchini', 0.0074195899), ('n07734744', 'mushroom', 0.0057988744)]

# %%
img_path = 'images/noodles_soup.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n04263257', 'soup_bowl', 0.80399686), ('n07590611', 'hot_pot', 0.10843373), ('n07584110', 'consomme', 0.011308012), ('n07871810', 'meat_loaf', 0.0092006465), ('n07579787', 'plate', 0.006999589)]

# %%
img_path = 'images/Leaf_01.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n03085013', 'computer_keyboard', 0.75814039), ('n04264628', 'space_bar', 0.065886252), ('n04505470', 'typewriter_keyboard', 0.031831473), ('n06785654', 'crossword_puzzle', 0.014880519), ('n02317335', 'starfish', 0.005862378)]

# %%
img_path = 'images/Leaf_02.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n04033901', 'quill', 0.38024825), ('n02281787', 'lycaenid', 0.022565937), ('n01644373', 'tree_frog', 0.020419547), ('n02264363', 'lacewing', 0.020097375), ('n02280649', 'cabbage_butterfly', 0.019541636)]

# %%
img_path = 'images/Leaf_03.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n03871628', 'packet', 0.046653751), ('n03291819', 'envelope', 0.03579852), ('n04476259', 'tray', 0.032637227), ('n04254120', 'soap_dispenser', 0.020224448), ('n03598930', 'jigsaw_puzzle', 0.018626658)]

# %%
img_path = 'images/bull_dog.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02108422', 'bull_mastiff', 0.38643369), ('n02110958', 'pug', 0.15397562), ('n02108915', 'French_bulldog', 0.044980034), ('n02093428', 'American_Staffordshire_terrier', 0.018074295), ('n02093256', 'Staffordshire_bullterrier', 0.014055671)]

# %%
img_path = 'images/pit_bull.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02093256', 'Staffordshire_bullterrier', 0.77109647), ('n02093428', 'American_Staffordshire_terrier', 0.22216094), ('n02108915', 'French_bulldog', 0.00073458673), ('n02096585', 'Boston_bull', 0.00057698198), ('n02105412', 'kelpie', 0.00031224609)]

# %%
img_path = 'images/foxhound.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02088238', 'basset', 0.846448), ('n02088364', 'beagle', 0.061020847), ('n02089867', 'Walker_hound', 0.033542715), ('n02088466', 'bloodhound', 0.014418359), ('n02089973', 'English_foxhound', 0.0049971589)]

# %%
img_path = 'images/border_collie.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02106166', 'Border_collie', 0.69825912), ('n02106030', 'collie', 0.19546206), ('n02105855', 'Shetland_sheepdog', 0.013488786), ('n02113186', 'Cardigan', 0.013457948), ('n02111277', 'Newfoundland', 0.0060541364)]

# %%
img_path = 'images/siberian_husky.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02110185', 'Siberian_husky', 0.75209755), ('n02109961', 'Eskimo_dog', 0.20943394), ('n02110063', 'malamute', 0.020496743), ('n02115641', 'dingo', 0.0040009436), ('n02114367', 'timber_wolf', 0.0019929342)]

# %%
img_path = 'images/bernese_mountain_dog.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02107683', 'Bernese_mountain_dog', 0.81618124), ('n02108000', 'EntleBucher', 0.054784294), ('n02107574', 'Greater_Swiss_Mountain_dog', 0.037102859), ('n02107908', 'Appenzeller', 0.033798523), ('n02101006', 'Gordon_setter', 0.0021162913)]

# %%
img_path = 'images/Common_Yellowthroat.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n01558993', 'robin', 0.28061277), ('n01531178', 'goldfinch', 0.22931097), ('n01828970', 'bee_eater', 0.1811164), ('n01530575', 'brambling', 0.15374199), ('n01532829', 'house_finch', 0.013144075)]

# %%
img_path = 'images/Winter_Wren.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n01601694', 'water_ouzel', 0.45507067), ('n01558993', 'robin', 0.097109199), ('n01560419', 'bulbul', 0.045699317), ('n01532829', 'house_finch', 0.042740945), ('n01833805', 'hummingbird', 0.035013426)]

# %%
img_path = 'images/Pine_Warbler.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n01534433', 'junco', 0.46363282), ('n01530575', 'brambling', 0.31794563), ('n01532829', 'house_finch', 0.12388864), ('n01558993', 'robin', 0.044940066), ('n01531178', 'goldfinch', 0.0042479127)]

# %%
img_path = 'images/Sage_Thrasher.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n01601694', 'water_ouzel', 0.17847568), ('n01833805', 'hummingbird', 0.11677071), ('n01797886', 'ruffed_grouse', 0.085069641), ('n01807496', 'partridge', 0.036462601), ('n01795545', 'black_grouse', 0.03542769)]

# %%
img_path = 'images/Lincoln_Sparrow.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02033041', 'dowitcher', 0.17387579), ('n01797886', 'ruffed_grouse', 0.14373846), ('n02011460', 'bittern', 0.072666042), ('n02028035', 'redshank', 0.057339903), ('n01807496', 'partridge', 0.041285258)]

# %%
img_path = 'images/Brown_Pelican.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02051845', 'pelican', 0.70535898), ('n02002556', 'white_stork', 0.029197279), ('n01614925', 'bald_eagle', 0.025426714), ('n01616318', 'vulture', 0.013600598), ('n01608432', 'kite', 0.010565682)]

# %%
img_path = 'images/Green_Jay.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n01580077', 'jay', 0.46460846), ('n01531178', 'goldfinch', 0.24556477), ('n01560419', 'bulbul', 0.040185794), ('n01828970', 'bee_eater', 0.036363192), ('n01843383', 'toucan', 0.014885672)]

# %%
img_path = 'images/Eared_Grebe.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n01855032', 'red-breasted_merganser', 0.13405073), ('n02028035', 'redshank', 0.088566303), ('n02027492', 'red-backed_sandpiper', 0.07890483), ('n02017213', 'European_gallinule', 0.06999065), ('n02018207', 'American_coot', 0.047315791)]

# %%
img_path = 'images/Pelagic_Cormorant.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n01795545', 'black_grouse', 0.15311475), ('n02018207', 'American_coot', 0.10295335), ('n01616318', 'vulture', 0.038272373), ('n02058221', 'albatross', 0.035720073), ('n01847000', 'drake', 0.032326825)]

# %%
img_path = 'images/Black_footed_Albatross.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02058221', 'albatross', 0.60514772), ('n02037110', 'oystercatcher', 0.049167555), ('n02018207', 'American_coot', 0.029449247), ('n02017213', 'European_gallinule', 0.022560751), ('n01847000', 'drake', 0.012672536)]

# %%
img_path = 'images/Heliconius_Erato.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02276258', 'admiral', 0.34319144), ('n02168699', 'long-horned_beetle', 0.023979094), ('n01629819', 'European_fire_salamander', 0.020424131), ('n02233338', 'cockroach', 0.015342141), ('n01843383', 'toucan', 0.013684157)]

# %%
img_path = 'images/Heliconius_Charitonius.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02281787', 'lycaenid', 0.14304341), ('n02277742', 'ringlet', 0.12766695), ('n02281406', 'sulphur_butterfly', 0.10126339), ('n02279972', 'monarch', 0.085621953), ('n02280649', 'cabbage_butterfly', 0.063828759)]

# %%
img_path = 'images/Junonia_Coenia.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02277742', 'ringlet', 0.8113206), ('n01669191', 'box_turtle', 0.036089707), ('n02276258', 'admiral', 0.0082093347), ('n01496331', 'electric_ray', 0.0048016324), ('n01667114', 'mud_turtle', 0.0044153789)]

# %%
img_path = 'images/Danaus_Plexippus.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02279972', 'monarch', 0.86057633), ('n02277742', 'ringlet', 0.041479856), ('n02281787', 'lycaenid', 0.031363234), ('n02276258', 'admiral', 0.0099377874), ('n02280649', 'cabbage_butterfly', 0.0092831291)]

# %%
img_path = 'images/Lycaena_Phlaeas.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02277742', 'ringlet', 0.84152406), ('n02281787', 'lycaenid', 0.097036667), ('n02276258', 'admiral', 0.034178395), ('n02281406', 'sulphur_butterfly', 0.011953158), ('n02280649', 'cabbage_butterfly', 0.0023121748)]

# %%
img_path = 'images/Nymphalis_Antiopa.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02276258', 'admiral', 0.92574137), ('n02281787', 'lycaenid', 0.036030155), ('n02277742', 'ringlet', 0.019838473), ('n01667114', 'mud_turtle', 0.00041831715), ('n01496331', 'electric_ray', 0.0004055459)]

# %%
img_path = 'images/Papilio_Cresphontes.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02276258', 'admiral', 0.14437087), ('n01629819', 'European_fire_salamander', 0.025047924), ('n01751748', 'sea_snake', 0.017680483), ('n03991062', 'pot', 0.017176762), ('n04507155', 'umbrella', 0.015404289)]

# %%
img_path = 'images/Pieris_Rapae.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02280649', 'cabbage_butterfly', 0.93990868), ('n02277742', 'ringlet', 0.0098752053), ('n02281406', 'sulphur_butterfly', 0.005909455), ('n02281787', 'lycaenid', 0.0015390585), ('n02692877', 'airship', 0.00043596345)]

# %%
img_path = 'images/Vanessa_Atalanta.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02276258', 'admiral', 0.98722678), ('n02281787', 'lycaenid', 0.0021207645), ('n02277742', 'ringlet', 0.0016643079), ('n02281406', 'sulphur_butterfly', 0.00083143805), ('n02279972', 'monarch', 0.00057543803)]

# %%
img_path = 'images/Vanessa_Cardui.jpg'
display_img(img_path)
pred(img_path)
# Out:
# Predicted: [('n02276258', 'admiral', 0.67857355), ('n02281406', 'sulphur_butterfly', 0.077097729), ('n02279972', 'monarch', 0.052020375), ('n02277742', 'ringlet', 0.014707147), ('n11879895', 'rapeseed', 0.01221006)]
